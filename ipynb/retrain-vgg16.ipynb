# %% [markdown]
# # Retraining Inception V3
#
# In this notebook, I will go over steps to retrain Inception V3 for the skin cancer dataset.

# %%
import os
from glob import glob

import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from tensorflow.keras.utils import to_categorical # convert to one-hot-encoding

from keras.preprocessing.image import ImageDataGenerator
from keras import layers
from keras import Model
from keras.applications.inception_v3 import InceptionV3, preprocess_input
from keras.optimizers.legacy import Adam
from keras.callbacks import ReduceLROnPlateau, EarlyStopping


# %matplotlib inline
import matplotlib.pyplot as plt
# Out:
# /opt/conda/lib/python3.10/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.24.3
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"

# %% [markdown]
# ## Load in the Dataset

# %%
X_train = np.load("/kaggle/input/npyfiles/npy/256_192_train.npy")

# %%
y_train = np.load("/kaggle/input/npyfiles/npy/train_labels.npy")

# %%
X_val = np.load("/kaggle/input/npyfiles/npy/256_192_val.npy")

# %%
y_val = np.load("/kaggle/input/npyfiles/npy/val_labels.npy")

# %%
X_train.shape, X_val.shape
# Out:
# ((8111, 192, 256, 3), (902, 192, 256, 3))

# %%
y_train.shape, y_val.shape
# Out:
# ((8111,), (902,))

# %%
y_train = to_categorical(y_train)
y_val = to_categorical(y_val)

# %%
y_train.shape, y_val.shape
# Out:
# ((8111, 7), (902, 7))

# %% [markdown]
# ## Load in Pretrained Inception Model

# %%
pre_trained_model = InceptionV3(input_shape=(192, 256, 3), include_top=False, weights="imagenet")
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/inception_v3/inception_v3_weights_tf_dim_ordering_tf_kernels_notop.h5
# 87910968/87910968 [==============================] - 0s 0us/step

# %%
for layer in pre_trained_model.layers:
    print(layer.name)
    layer.trainable = False
    
print(len(pre_trained_model.layers))
# Out:
# input_1
# conv2d
# batch_normalization
# activation
# conv2d_1
# batch_normalization_1
# activation_1
# conv2d_2
# batch_normalization_2
# activation_2
# max_pooling2d
# conv2d_3
# batch_normalization_3
# activation_3
# conv2d_4
# batch_normalization_4
# activation_4
# max_pooling2d_1
# conv2d_8
# batch_normalization_8
# activation_8
# conv2d_6
# conv2d_9
# batch_normalization_6
# batch_normalization_9
# activation_6
# activation_9
# average_pooling2d
# conv2d_5
# conv2d_7
# conv2d_10
# conv2d_11
# batch_normalization_5
# batch_normalization_7
# batch_normalization_10
# batch_normalization_11
# activation_5
# activation_7
# activation_10
# activation_11
# mixed0
# conv2d_15
# batch_normalization_15
# activation_15
# conv2d_13
# conv2d_16
# batch_normalization_13
# batch_normalization_16
# activation_13
# activation_16
# average_pooling2d_1
# conv2d_12
# conv2d_14
# conv2d_17
# conv2d_18
# batch_normalization_12
# batch_normalization_14
# batch_normalization_17
# batch_normalization_18
# activation_12
# activation_14
# activation_17
# activation_18
# mixed1
# conv2d_22
# batch_normalization_22
# activation_22
# conv2d_20
# conv2d_23
# batch_normalization_20
# batch_normalization_23
# activation_20
# activation_23
# average_pooling2d_2
# conv2d_19
# conv2d_21
# conv2d_24
# conv2d_25
# batch_normalization_19
# batch_normalization_21
# batch_normalization_24
# batch_normalization_25
# activation_19
# activation_21
# activation_24
# activation_25
# mixed2
# conv2d_27
# batch_normalization_27
# activation_27
# conv2d_28
# batch_normalization_28
# activation_28
# conv2d_26
# conv2d_29
# batch_normalization_26
# batch_normalization_29
# activation_26
# activation_29
# max_pooling2d_2
# mixed3
# conv2d_34
# batch_normalization_34
# activation_34
# conv2d_35
# batch_normalization_35
# activation_35
# conv2d_31
# conv2d_36
# batch_normalization_31
# batch_normalization_36
# activation_31
# activation_36
# conv2d_32
# conv2d_37
# batch_normalization_32
# batch_normalization_37
# activation_32
# activation_37
# average_pooling2d_3
# conv2d_30
# conv2d_33
# conv2d_38
# conv2d_39
# batch_normalization_30
# batch_normalization_33
# batch_normalization_38
# batch_normalization_39
# activation_30
# activation_33
# activation_38
# activation_39
# mixed4
# conv2d_44
# batch_normalization_44
# activation_44
# conv2d_45
# batch_normalization_45
# activation_45
# conv2d_41
# conv2d_46
# batch_normalization_41
# batch_normalization_46
# activation_41
# activation_46
# conv2d_42
# conv2d_47
# batch_normalization_42
# batch_normalization_47
# activation_42
# activation_47
# average_pooling2d_4
# conv2d_40
# conv2d_43
# conv2d_48
# conv2d_49
# batch_normalization_40
# batch_normalization_43
# batch_normalization_48
# batch_normalization_49
# activation_40
# activation_43
# activation_48
# activation_49
# mixed5
# conv2d_54
# batch_normalization_54
# activation_54
# conv2d_55
# batch_normalization_55
# activation_55
# conv2d_51
# conv2d_56
# batch_normalization_51
# batch_normalization_56
# activation_51
# activation_56
# conv2d_52
# conv2d_57
# batch_normalization_52
# batch_normalization_57
# activation_52
# activation_57
# average_pooling2d_5
# conv2d_50
# conv2d_53
# conv2d_58
# conv2d_59
# batch_normalization_50
# batch_normalization_53
# batch_normalization_58
# batch_normalization_59
# activation_50
# activation_53
# activation_58
# activation_59
# mixed6
# conv2d_64
# batch_normalization_64
# activation_64
# conv2d_65
# batch_normalization_65
# activation_65
# conv2d_61
# conv2d_66
# batch_normalization_61
# batch_normalization_66
# activation_61
# activation_66
# conv2d_62
# conv2d_67
# batch_normalization_62
# batch_normalization_67
# activation_62
# activation_67
# average_pooling2d_6
# conv2d_60
# conv2d_63
# conv2d_68
# conv2d_69
# batch_normalization_60
# batch_normalization_63
# batch_normalization_68
# batch_normalization_69
# activation_60
# activation_63
# activation_68
# activation_69
# mixed7
# conv2d_72
# batch_normalization_72
# activation_72
# conv2d_73
# batch_normalization_73
# activation_73
# conv2d_70
# conv2d_74
# batch_normalization_70
# batch_normalization_74
# activation_70
# activation_74
# conv2d_71
# conv2d_75
# batch_normalization_71
# batch_normalization_75
# activation_71
# activation_75
# max_pooling2d_3
# mixed8
# conv2d_80
# batch_normalization_80
# activation_80
# conv2d_77
# conv2d_81
# batch_normalization_77
# batch_normalization_81
# activation_77
# activation_81
# conv2d_78
# conv2d_79
# conv2d_82
# conv2d_83
# average_pooling2d_7
# conv2d_76
# batch_normalization_78
# batch_normalization_79
# batch_normalization_82
# batch_normalization_83
# conv2d_84
# batch_normalization_76
# activation_78
# activation_79
# activation_82
# activation_83
# batch_normalization_84
# activation_76
# mixed9_0
# concatenate
# activation_84
# mixed9
# conv2d_89
# batch_normalization_89
# activation_89
# conv2d_86
# conv2d_90
# batch_normalization_86
# batch_normalization_90
# activation_86
# activation_90
# conv2d_87
# conv2d_88
# conv2d_91
# conv2d_92
# average_pooling2d_8
# conv2d_85
# batch_normalization_87
# batch_normalization_88
# batch_normalization_91
# batch_normalization_92
# conv2d_93
# batch_normalization_85
# activation_87
# activation_88
# activation_91
# activation_92
# batch_normalization_93
# activation_85
# mixed9_1
# concatenate_1
# activation_93
# mixed10
# 311

# %%
last_layer = pre_trained_model.get_layer('mixed10')
print('last layer output shape:', last_layer.output_shape)
last_output = last_layer.output
# Out:
# last layer output shape: (None, 4, 6, 2048)

# %% [markdown]
# ## Define the Model

# %%
# Flatten the output layer to 1 dimension
x = layers.GlobalMaxPooling2D()(last_output)
# Add a fully connected layer with 512 hidden units and ReLU activation
x = layers.Dense(512, activation='relu')(x)
# Add a dropout rate of 0.7
x = layers.Dropout(0.5)(x)
# Add a final sigmoid layer for classification
x = layers.Dense(7, activation='softmax')(x)

# Configure and compile the model

model = Model(pre_trained_model.input, x)
optimizer = Adam(lr=0.0001, beta_1=0.9, beta_2=0.999, epsilon=None, decay=0.0, amsgrad=True)
model.compile(loss='categorical_crossentropy',
              optimizer=optimizer,
              metrics=['accuracy'])
# Out:
# /opt/conda/lib/python3.10/site-packages/keras/src/optimizers/legacy/adam.py:118: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super().__init__(name, **kwargs)

# %%
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_1 (InputLayer)        [(None, 192, 256, 3)]        0         []
#
#  conv2d (Conv2D)             (None, 95, 127, 32)          864       ['input_1[0][0]']
#
#  batch_normalization (Batch  (None, 95, 127, 32)          96        ['conv2d[0][0]']
#  Normalization)
#
#  activation (Activation)     (None, 95, 127, 32)          0         ['batch_normalization[0][0]']
#
#  conv2d_1 (Conv2D)           (None, 93, 125, 32)          9216      ['activation[0][0]']
#
#  batch_normalization_1 (Bat  (None, 93, 125, 32)          96        ['conv2d_1[0][0]']
#  chNormalization)
#
#  activation_1 (Activation)   (None, 93, 125, 32)          0         ['batch_normalization_1[0][0]'
#                                                                     ]
#
#  conv2d_2 (Conv2D)           (None, 93, 125, 64)          18432     ['activation_1[0][0]']
#
#  batch_normalization_2 (Bat  (None, 93, 125, 64)          192       ['conv2d_2[0][0]']
#  chNormalization)
#
#  activation_2 (Activation)   (None, 93, 125, 64)          0         ['batch_normalization_2[0][0]'
#                                                                     ]
#
#  max_pooling2d (MaxPooling2  (None, 46, 62, 64)           0         ['activation_2[0][0]']
#  D)
#
#  conv2d_3 (Conv2D)           (None, 46, 62, 80)           5120      ['max_pooling2d[0][0]']
#
#  batch_normalization_3 (Bat  (None, 46, 62, 80)           240       ['conv2d_3[0][0]']
#  chNormalization)
#
#  activation_3 (Activation)   (None, 46, 62, 80)           0         ['batch_normalization_3[0][0]'
#                                                                     ]
#
#  conv2d_4 (Conv2D)           (None, 44, 60, 192)          138240    ['activation_3[0][0]']
#
#  batch_normalization_4 (Bat  (None, 44, 60, 192)          576       ['conv2d_4[0][0]']
#  chNormalization)
#
#  activation_4 (Activation)   (None, 44, 60, 192)          0         ['batch_normalization_4[0][0]'
#                                                                     ]
#
#  max_pooling2d_1 (MaxPoolin  (None, 21, 29, 192)          0         ['activation_4[0][0]']
#  g2D)
#
#  conv2d_8 (Conv2D)           (None, 21, 29, 64)           12288     ['max_pooling2d_1[0][0]']
#
#  batch_normalization_8 (Bat  (None, 21, 29, 64)           192       ['conv2d_8[0][0]']
#  chNormalization)
#
#  activation_8 (Activation)   (None, 21, 29, 64)           0         ['batch_normalization_8[0][0]'
#                                                                     ]
#
#  conv2d_6 (Conv2D)           (None, 21, 29, 48)           9216      ['max_pooling2d_1[0][0]']
#
#  conv2d_9 (Conv2D)           (None, 21, 29, 96)           55296     ['activation_8[0][0]']
#
#  batch_normalization_6 (Bat  (None, 21, 29, 48)           144       ['conv2d_6[0][0]']
#  chNormalization)
#
#  batch_normalization_9 (Bat  (None, 21, 29, 96)           288       ['conv2d_9[0][0]']
#  chNormalization)
#
#  activation_6 (Activation)   (None, 21, 29, 48)           0         ['batch_normalization_6[0][0]'
#                                                                     ]
#
#  activation_9 (Activation)   (None, 21, 29, 96)           0         ['batch_normalization_9[0][0]'
#                                                                     ]
#
#  average_pooling2d (Average  (None, 21, 29, 192)          0         ['max_pooling2d_1[0][0]']
#  Pooling2D)
#
#  conv2d_5 (Conv2D)           (None, 21, 29, 64)           12288     ['max_pooling2d_1[0][0]']
#
#  conv2d_7 (Conv2D)           (None, 21, 29, 64)           76800     ['activation_6[0][0]']
#
#  conv2d_10 (Conv2D)          (None, 21, 29, 96)           82944     ['activation_9[0][0]']
#
#  conv2d_11 (Conv2D)          (None, 21, 29, 32)           6144      ['average_pooling2d[0][0]']
#
#  batch_normalization_5 (Bat  (None, 21, 29, 64)           192       ['conv2d_5[0][0]']
#  chNormalization)
#
#  batch_normalization_7 (Bat  (None, 21, 29, 64)           192       ['conv2d_7[0][0]']
#  chNormalization)
#
#  batch_normalization_10 (Ba  (None, 21, 29, 96)           288       ['conv2d_10[0][0]']
#  tchNormalization)
#
#  batch_normalization_11 (Ba  (None, 21, 29, 32)           96        ['conv2d_11[0][0]']
#  tchNormalization)
#
#  activation_5 (Activation)   (None, 21, 29, 64)           0         ['batch_normalization_5[0][0]'
#                                                                     ]
#
#  activation_7 (Activation)   (None, 21, 29, 64)           0         ['batch_normalization_7[0][0]'
#                                                                     ]
#
#  activation_10 (Activation)  (None, 21, 29, 96)           0         ['batch_normalization_10[0][0]
#                                                                     ']
#
#  activation_11 (Activation)  (None, 21, 29, 32)           0         ['batch_normalization_11[0][0]
#                                                                     ']
#
#  mixed0 (Concatenate)        (None, 21, 29, 256)          0         ['activation_5[0][0]',
#                                                                      'activation_7[0][0]',
#                                                                      'activation_10[0][0]',
#                                                                      'activation_11[0][0]']
#
#  conv2d_15 (Conv2D)          (None, 21, 29, 64)           16384     ['mixed0[0][0]']
#
#  batch_normalization_15 (Ba  (None, 21, 29, 64)           192       ['conv2d_15[0][0]']
#  tchNormalization)
#
#  activation_15 (Activation)  (None, 21, 29, 64)           0         ['batch_normalization_15[0][0]
#                                                                     ']
#
#  conv2d_13 (Conv2D)          (None, 21, 29, 48)           12288     ['mixed0[0][0]']
#
#  conv2d_16 (Conv2D)          (None, 21, 29, 96)           55296     ['activation_15[0][0]']
#
#  batch_normalization_13 (Ba  (None, 21, 29, 48)           144       ['conv2d_13[0][0]']
#  tchNormalization)
#
#  batch_normalization_16 (Ba  (None, 21, 29, 96)           288       ['conv2d_16[0][0]']
#  tchNormalization)
#
#  activation_13 (Activation)  (None, 21, 29, 48)           0         ['batch_normalization_13[0][0]
#                                                                     ']
#
#  activation_16 (Activation)  (None, 21, 29, 96)           0         ['batch_normalization_16[0][0]
#                                                                     ']
#
#  average_pooling2d_1 (Avera  (None, 21, 29, 256)          0         ['mixed0[0][0]']
#  gePooling2D)
#
#  conv2d_12 (Conv2D)          (None, 21, 29, 64)           16384     ['mixed0[0][0]']
#
#  conv2d_14 (Conv2D)          (None, 21, 29, 64)           76800     ['activation_13[0][0]']
#
#  conv2d_17 (Conv2D)          (None, 21, 29, 96)           82944     ['activation_16[0][0]']
#
#  conv2d_18 (Conv2D)          (None, 21, 29, 64)           16384     ['average_pooling2d_1[0][0]']
#
#  batch_normalization_12 (Ba  (None, 21, 29, 64)           192       ['conv2d_12[0][0]']
#  tchNormalization)
#
#  batch_normalization_14 (Ba  (None, 21, 29, 64)           192       ['conv2d_14[0][0]']
#  tchNormalization)
#
#  batch_normalization_17 (Ba  (None, 21, 29, 96)           288       ['conv2d_17[0][0]']
#  tchNormalization)
#
#  batch_normalization_18 (Ba  (None, 21, 29, 64)           192       ['conv2d_18[0][0]']
#  tchNormalization)
#
#  activation_12 (Activation)  (None, 21, 29, 64)           0         ['batch_normalization_12[0][0]
#                                                                     ']
#
#  activation_14 (Activation)  (None, 21, 29, 64)           0         ['batch_normalization_14[0][0]
#                                                                     ']
#
#  activation_17 (Activation)  (None, 21, 29, 96)           0         ['batch_normalization_17[0][0]
#                                                                     ']
#
#  activation_18 (Activation)  (None, 21, 29, 64)           0         ['batch_normalization_18[0][0]
#                                                                     ']
#
#  mixed1 (Concatenate)        (None, 21, 29, 288)          0         ['activation_12[0][0]',
#                                                                      'activation_14[0][0]',
#                                                                      'activation_17[0][0]',
#                                                                      'activation_18[0][0]']
#
#  conv2d_22 (Conv2D)          (None, 21, 29, 64)           18432     ['mixed1[0][0]']
#
#  batch_normalization_22 (Ba  (None, 21, 29, 64)           192       ['conv2d_22[0][0]']
#  tchNormalization)
#
#  activation_22 (Activation)  (None, 21, 29, 64)           0         ['batch_normalization_22[0][0]
#                                                                     ']
#
#  conv2d_20 (Conv2D)          (None, 21, 29, 48)           13824     ['mixed1[0][0]']
#
#  conv2d_23 (Conv2D)          (None, 21, 29, 96)           55296     ['activation_22[0][0]']
#
#  batch_normalization_20 (Ba  (None, 21, 29, 48)           144       ['conv2d_20[0][0]']
#  tchNormalization)
#
#  batch_normalization_23 (Ba  (None, 21, 29, 96)           288       ['conv2d_23[0][0]']
#  tchNormalization)
#
#  activation_20 (Activation)  (None, 21, 29, 48)           0         ['batch_normalization_20[0][0]
#                                                                     ']
#
#  activation_23 (Activation)  (None, 21, 29, 96)           0         ['batch_normalization_23[0][0]
#                                                                     ']
#
#  average_pooling2d_2 (Avera  (None, 21, 29, 288)          0         ['mixed1[0][0]']
#  gePooling2D)
#
#  conv2d_19 (Conv2D)          (None, 21, 29, 64)           18432     ['mixed1[0][0]']
#
#  conv2d_21 (Conv2D)          (None, 21, 29, 64)           76800     ['activation_20[0][0]']
#
#  conv2d_24 (Conv2D)          (None, 21, 29, 96)           82944     ['activation_23[0][0]']
#
#  conv2d_25 (Conv2D)          (None, 21, 29, 64)           18432     ['average_pooling2d_2[0][0]']
#
#  batch_normalization_19 (Ba  (None, 21, 29, 64)           192       ['conv2d_19[0][0]']
#  tchNormalization)
#
#  batch_normalization_21 (Ba  (None, 21, 29, 64)           192       ['conv2d_21[0][0]']
#  tchNormalization)
#
#  batch_normalization_24 (Ba  (None, 21, 29, 96)           288       ['conv2d_24[0][0]']
#  tchNormalization)
#
#  batch_normalization_25 (Ba  (None, 21, 29, 64)           192       ['conv2d_25[0][0]']
#  tchNormalization)
#
#  activation_19 (Activation)  (None, 21, 29, 64)           0         ['batch_normalization_19[0][0]
#                                                                     ']
#
#  activation_21 (Activation)  (None, 21, 29, 64)           0         ['batch_normalization_21[0][0]
#                                                                     ']
#
#  activation_24 (Activation)  (None, 21, 29, 96)           0         ['batch_normalization_24[0][0]
#                                                                     ']
#
#  activation_25 (Activation)  (None, 21, 29, 64)           0         ['batch_normalization_25[0][0]
#                                                                     ']
#
#  mixed2 (Concatenate)        (None, 21, 29, 288)          0         ['activation_19[0][0]',
#                                                                      'activation_21[0][0]',
#                                                                      'activation_24[0][0]',
#                                                                      'activation_25[0][0]']
#
#  conv2d_27 (Conv2D)          (None, 21, 29, 64)           18432     ['mixed2[0][0]']
#
#  batch_normalization_27 (Ba  (None, 21, 29, 64)           192       ['conv2d_27[0][0]']
#  tchNormalization)
#
#  activation_27 (Activation)  (None, 21, 29, 64)           0         ['batch_normalization_27[0][0]
#                                                                     ']
#
#  conv2d_28 (Conv2D)          (None, 21, 29, 96)           55296     ['activation_27[0][0]']
#
#  batch_normalization_28 (Ba  (None, 21, 29, 96)           288       ['conv2d_28[0][0]']
#  tchNormalization)
#
#  activation_28 (Activation)  (None, 21, 29, 96)           0         ['batch_normalization_28[0][0]
#                                                                     ']
#
#  conv2d_26 (Conv2D)          (None, 10, 14, 384)          995328    ['mixed2[0][0]']
#
#  conv2d_29 (Conv2D)          (None, 10, 14, 96)           82944     ['activation_28[0][0]']
#
#  batch_normalization_26 (Ba  (None, 10, 14, 384)          1152      ['conv2d_26[0][0]']
#  tchNormalization)
#
#  batch_normalization_29 (Ba  (None, 10, 14, 96)           288       ['conv2d_29[0][0]']
#  tchNormalization)
#
#  activation_26 (Activation)  (None, 10, 14, 384)          0         ['batch_normalization_26[0][0]
#                                                                     ']
#
#  activation_29 (Activation)  (None, 10, 14, 96)           0         ['batch_normalization_29[0][0]
#                                                                     ']
#
#  max_pooling2d_2 (MaxPoolin  (None, 10, 14, 288)          0         ['mixed2[0][0]']
#  g2D)
#
#  mixed3 (Concatenate)        (None, 10, 14, 768)          0         ['activation_26[0][0]',
#                                                                      'activation_29[0][0]',
#                                                                      'max_pooling2d_2[0][0]']
#
#  conv2d_34 (Conv2D)          (None, 10, 14, 128)          98304     ['mixed3[0][0]']
#
#  batch_normalization_34 (Ba  (None, 10, 14, 128)          384       ['conv2d_34[0][0]']
#  tchNormalization)
#
#  activation_34 (Activation)  (None, 10, 14, 128)          0         ['batch_normalization_34[0][0]
#                                                                     ']
#
#  conv2d_35 (Conv2D)          (None, 10, 14, 128)          114688    ['activation_34[0][0]']
#
#  batch_normalization_35 (Ba  (None, 10, 14, 128)          384       ['conv2d_35[0][0]']
#  tchNormalization)
#
#  activation_35 (Activation)  (None, 10, 14, 128)          0         ['batch_normalization_35[0][0]
#                                                                     ']
#
#  conv2d_31 (Conv2D)          (None, 10, 14, 128)          98304     ['mixed3[0][0]']
#
#  conv2d_36 (Conv2D)          (None, 10, 14, 128)          114688    ['activation_35[0][0]']
#
#  batch_normalization_31 (Ba  (None, 10, 14, 128)          384       ['conv2d_31[0][0]']
#  tchNormalization)
#
#  batch_normalization_36 (Ba  (None, 10, 14, 128)          384       ['conv2d_36[0][0]']
#  tchNormalization)
#
#  activation_31 (Activation)  (None, 10, 14, 128)          0         ['batch_normalization_31[0][0]
#                                                                     ']
#
#  activation_36 (Activation)  (None, 10, 14, 128)          0         ['batch_normalization_36[0][0]
#                                                                     ']
#
#  conv2d_32 (Conv2D)          (None, 10, 14, 128)          114688    ['activation_31[0][0]']
#
#  conv2d_37 (Conv2D)          (None, 10, 14, 128)          114688    ['activation_36[0][0]']
#
#  batch_normalization_32 (Ba  (None, 10, 14, 128)          384       ['conv2d_32[0][0]']
#  tchNormalization)
#
#  batch_normalization_37 (Ba  (None, 10, 14, 128)          384       ['conv2d_37[0][0]']
#  tchNormalization)
#
#  activation_32 (Activation)  (None, 10, 14, 128)          0         ['batch_normalization_32[0][0]
#                                                                     ']
#
#  activation_37 (Activation)  (None, 10, 14, 128)          0         ['batch_normalization_37[0][0]
#                                                                     ']
#
#  average_pooling2d_3 (Avera  (None, 10, 14, 768)          0         ['mixed3[0][0]']
#  gePooling2D)
#
#  conv2d_30 (Conv2D)          (None, 10, 14, 192)          147456    ['mixed3[0][0]']
#
#  conv2d_33 (Conv2D)          (None, 10, 14, 192)          172032    ['activation_32[0][0]']
#
#  conv2d_38 (Conv2D)          (None, 10, 14, 192)          172032    ['activation_37[0][0]']
#
#  conv2d_39 (Conv2D)          (None, 10, 14, 192)          147456    ['average_pooling2d_3[0][0]']
#
#  batch_normalization_30 (Ba  (None, 10, 14, 192)          576       ['conv2d_30[0][0]']
#  tchNormalization)
#
#  batch_normalization_33 (Ba  (None, 10, 14, 192)          576       ['conv2d_33[0][0]']
#  tchNormalization)
#
#  batch_normalization_38 (Ba  (None, 10, 14, 192)          576       ['conv2d_38[0][0]']
#  tchNormalization)
#
#  batch_normalization_39 (Ba  (None, 10, 14, 192)          576       ['conv2d_39[0][0]']
#  tchNormalization)
#
#  activation_30 (Activation)  (None, 10, 14, 192)          0         ['batch_normalization_30[0][0]
#                                                                     ']
#
#  activation_33 (Activation)  (None, 10, 14, 192)          0         ['batch_normalization_33[0][0]
#                                                                     ']
#
#  activation_38 (Activation)  (None, 10, 14, 192)          0         ['batch_normalization_38[0][0]
#                                                                     ']
#
#  activation_39 (Activation)  (None, 10, 14, 192)          0         ['batch_normalization_39[0][0]
#                                                                     ']
#
#  mixed4 (Concatenate)        (None, 10, 14, 768)          0         ['activation_30[0][0]',
#                                                                      'activation_33[0][0]',
#                                                                      'activation_38[0][0]',
#                                                                      'activation_39[0][0]']
#
#  conv2d_44 (Conv2D)          (None, 10, 14, 160)          122880    ['mixed4[0][0]']
#
#  batch_normalization_44 (Ba  (None, 10, 14, 160)          480       ['conv2d_44[0][0]']
#  tchNormalization)
#
#  activation_44 (Activation)  (None, 10, 14, 160)          0         ['batch_normalization_44[0][0]
#                                                                     ']
#
#  conv2d_45 (Conv2D)          (None, 10, 14, 160)          179200    ['activation_44[0][0]']
#
#  batch_normalization_45 (Ba  (None, 10, 14, 160)          480       ['conv2d_45[0][0]']
#  tchNormalization)
#
#  activation_45 (Activation)  (None, 10, 14, 160)          0         ['batch_normalization_45[0][0]
#                                                                     ']
#
#  conv2d_41 (Conv2D)          (None, 10, 14, 160)          122880    ['mixed4[0][0]']
#
#  conv2d_46 (Conv2D)          (None, 10, 14, 160)          179200    ['activation_45[0][0]']
#
#  batch_normalization_41 (Ba  (None, 10, 14, 160)          480       ['conv2d_41[0][0]']
#  tchNormalization)
#
#  batch_normalization_46 (Ba  (None, 10, 14, 160)          480       ['conv2d_46[0][0]']
#  tchNormalization)
#
#  activation_41 (Activation)  (None, 10, 14, 160)          0         ['batch_normalization_41[0][0]
#                                                                     ']
#
#  activation_46 (Activation)  (None, 10, 14, 160)          0         ['batch_normalization_46[0][0]
#                                                                     ']
#
#  conv2d_42 (Conv2D)          (None, 10, 14, 160)          179200    ['activation_41[0][0]']
#
#  conv2d_47 (Conv2D)          (None, 10, 14, 160)          179200    ['activation_46[0][0]']
#
#  batch_normalization_42 (Ba  (None, 10, 14, 160)          480       ['conv2d_42[0][0]']
#  tchNormalization)
#
#  batch_normalization_47 (Ba  (None, 10, 14, 160)          480       ['conv2d_47[0][0]']
#  tchNormalization)
#
#  activation_42 (Activation)  (None, 10, 14, 160)          0         ['batch_normalization_42[0][0]
#                                                                     ']
#
#  activation_47 (Activation)  (None, 10, 14, 160)          0         ['batch_normalization_47[0][0]
#                                                                     ']
#
#  average_pooling2d_4 (Avera  (None, 10, 14, 768)          0         ['mixed4[0][0]']
#  gePooling2D)
#
#  conv2d_40 (Conv2D)          (None, 10, 14, 192)          147456    ['mixed4[0][0]']
#
#  conv2d_43 (Conv2D)          (None, 10, 14, 192)          215040    ['activation_42[0][0]']
#
#  conv2d_48 (Conv2D)          (None, 10, 14, 192)          215040    ['activation_47[0][0]']
#
#  conv2d_49 (Conv2D)          (None, 10, 14, 192)          147456    ['average_pooling2d_4[0][0]']
#
#  batch_normalization_40 (Ba  (None, 10, 14, 192)          576       ['conv2d_40[0][0]']
#  tchNormalization)
#
#  batch_normalization_43 (Ba  (None, 10, 14, 192)          576       ['conv2d_43[0][0]']
#  tchNormalization)
#
#  batch_normalization_48 (Ba  (None, 10, 14, 192)          576       ['conv2d_48[0][0]']
#  tchNormalization)
#
#  batch_normalization_49 (Ba  (None, 10, 14, 192)          576       ['conv2d_49[0][0]']
#  tchNormalization)
#
#  activation_40 (Activation)  (None, 10, 14, 192)          0         ['batch_normalization_40[0][0]
#                                                                     ']
#
#  activation_43 (Activation)  (None, 10, 14, 192)          0         ['batch_normalization_43[0][0]
#                                                                     ']
#
#  activation_48 (Activation)  (None, 10, 14, 192)          0         ['batch_normalization_48[0][0]
#                                                                     ']
#
#  activation_49 (Activation)  (None, 10, 14, 192)          0         ['batch_normalization_49[0][0]
#                                                                     ']
#
#  mixed5 (Concatenate)        (None, 10, 14, 768)          0         ['activation_40[0][0]',
#                                                                      'activation_43[0][0]',
#                                                                      'activation_48[0][0]',
#                                                                      'activation_49[0][0]']
#
#  conv2d_54 (Conv2D)          (None, 10, 14, 160)          122880    ['mixed5[0][0]']
#
#  batch_normalization_54 (Ba  (None, 10, 14, 160)          480       ['conv2d_54[0][0]']
#  tchNormalization)
#
#  activation_54 (Activation)  (None, 10, 14, 160)          0         ['batch_normalization_54[0][0]
#                                                                     ']
#
#  conv2d_55 (Conv2D)          (None, 10, 14, 160)          179200    ['activation_54[0][0]']
#
#  batch_normalization_55 (Ba  (None, 10, 14, 160)          480       ['conv2d_55[0][0]']
#  tchNormalization)
#
#  activation_55 (Activation)  (None, 10, 14, 160)          0         ['batch_normalization_55[0][0]
#                                                                     ']
#
#  conv2d_51 (Conv2D)          (None, 10, 14, 160)          122880    ['mixed5[0][0]']
#
#  conv2d_56 (Conv2D)          (None, 10, 14, 160)          179200    ['activation_55[0][0]']
#
#  batch_normalization_51 (Ba  (None, 10, 14, 160)          480       ['conv2d_51[0][0]']
#  tchNormalization)
#
#  batch_normalization_56 (Ba  (None, 10, 14, 160)          480       ['conv2d_56[0][0]']
#  tchNormalization)
#
#  activation_51 (Activation)  (None, 10, 14, 160)          0         ['batch_normalization_51[0][0]
# ...
#
#  conv2d_78 (Conv2D)          (None, 4, 6, 384)            442368    ['activation_77[0][0]']
#
#  conv2d_79 (Conv2D)          (None, 4, 6, 384)            442368    ['activation_77[0][0]']
#
#  conv2d_82 (Conv2D)          (None, 4, 6, 384)            442368    ['activation_81[0][0]']
#
#  conv2d_83 (Conv2D)          (None, 4, 6, 384)            442368    ['activation_81[0][0]']
#
#  average_pooling2d_7 (Avera  (None, 4, 6, 1280)           0         ['mixed8[0][0]']
#  gePooling2D)
#
#  conv2d_76 (Conv2D)          (None, 4, 6, 320)            409600    ['mixed8[0][0]']
#
#  batch_normalization_78 (Ba  (None, 4, 6, 384)            1152      ['conv2d_78[0][0]']
#  tchNormalization)
#
#  batch_normalization_79 (Ba  (None, 4, 6, 384)            1152      ['conv2d_79[0][0]']
#  tchNormalization)
#
#  batch_normalization_82 (Ba  (None, 4, 6, 384)            1152      ['conv2d_82[0][0]']
#  tchNormalization)
#
#  batch_normalization_83 (Ba  (None, 4, 6, 384)            1152      ['conv2d_83[0][0]']
#  tchNormalization)
#
#  conv2d_84 (Conv2D)          (None, 4, 6, 192)            245760    ['average_pooling2d_7[0][0]']
#
#  batch_normalization_76 (Ba  (None, 4, 6, 320)            960       ['conv2d_76[0][0]']
#  tchNormalization)
#
#  activation_78 (Activation)  (None, 4, 6, 384)            0         ['batch_normalization_78[0][0]
#                                                                     ']
#
#  activation_79 (Activation)  (None, 4, 6, 384)            0         ['batch_normalization_79[0][0]
#                                                                     ']
#
#  activation_82 (Activation)  (None, 4, 6, 384)            0         ['batch_normalization_82[0][0]
#                                                                     ']
#
#  activation_83 (Activation)  (None, 4, 6, 384)            0         ['batch_normalization_83[0][0]
#                                                                     ']
#
#  batch_normalization_84 (Ba  (None, 4, 6, 192)            576       ['conv2d_84[0][0]']
#  tchNormalization)
#
#  activation_76 (Activation)  (None, 4, 6, 320)            0         ['batch_normalization_76[0][0]
#                                                                     ']
#
#  mixed9_0 (Concatenate)      (None, 4, 6, 768)            0         ['activation_78[0][0]',
#                                                                      'activation_79[0][0]']
#
#  concatenate (Concatenate)   (None, 4, 6, 768)            0         ['activation_82[0][0]',
#                                                                      'activation_83[0][0]']
#
#  activation_84 (Activation)  (None, 4, 6, 192)            0         ['batch_normalization_84[0][0]
#                                                                     ']
#
#  mixed9 (Concatenate)        (None, 4, 6, 2048)           0         ['activation_76[0][0]',
#                                                                      'mixed9_0[0][0]',
#                                                                      'concatenate[0][0]',
#                                                                      'activation_84[0][0]']
#
#  conv2d_89 (Conv2D)          (None, 4, 6, 448)            917504    ['mixed9[0][0]']
#
#  batch_normalization_89 (Ba  (None, 4, 6, 448)            1344      ['conv2d_89[0][0]']
#  tchNormalization)
#
#  activation_89 (Activation)  (None, 4, 6, 448)            0         ['batch_normalization_89[0][0]
#                                                                     ']
#
#  conv2d_86 (Conv2D)          (None, 4, 6, 384)            786432    ['mixed9[0][0]']
#
#  conv2d_90 (Conv2D)          (None, 4, 6, 384)            1548288   ['activation_89[0][0]']
#
#  batch_normalization_86 (Ba  (None, 4, 6, 384)            1152      ['conv2d_86[0][0]']
#  tchNormalization)
#
#  batch_normalization_90 (Ba  (None, 4, 6, 384)            1152      ['conv2d_90[0][0]']
#  tchNormalization)
#
#  activation_86 (Activation)  (None, 4, 6, 384)            0         ['batch_normalization_86[0][0]
#                                                                     ']
#
#  activation_90 (Activation)  (None, 4, 6, 384)            0         ['batch_normalization_90[0][0]
#                                                                     ']
#
#  conv2d_87 (Conv2D)          (None, 4, 6, 384)            442368    ['activation_86[0][0]']
#
#  conv2d_88 (Conv2D)          (None, 4, 6, 384)            442368    ['activation_86[0][0]']
#
#  conv2d_91 (Conv2D)          (None, 4, 6, 384)            442368    ['activation_90[0][0]']
#
#  conv2d_92 (Conv2D)          (None, 4, 6, 384)            442368    ['activation_90[0][0]']
#
#  average_pooling2d_8 (Avera  (None, 4, 6, 2048)           0         ['mixed9[0][0]']
#  gePooling2D)
#
#  conv2d_85 (Conv2D)          (None, 4, 6, 320)            655360    ['mixed9[0][0]']
#
#  batch_normalization_87 (Ba  (None, 4, 6, 384)            1152      ['conv2d_87[0][0]']
#  tchNormalization)
#
#  batch_normalization_88 (Ba  (None, 4, 6, 384)            1152      ['conv2d_88[0][0]']
#  tchNormalization)
#
#  batch_normalization_91 (Ba  (None, 4, 6, 384)            1152      ['conv2d_91[0][0]']
#  tchNormalization)
#
#  batch_normalization_92 (Ba  (None, 4, 6, 384)            1152      ['conv2d_92[0][0]']
#  tchNormalization)
#
#  conv2d_93 (Conv2D)          (None, 4, 6, 192)            393216    ['average_pooling2d_8[0][0]']
#
#  batch_normalization_85 (Ba  (None, 4, 6, 320)            960       ['conv2d_85[0][0]']
#  tchNormalization)
#
#  activation_87 (Activation)  (None, 4, 6, 384)            0         ['batch_normalization_87[0][0]
#                                                                     ']
#
#  activation_88 (Activation)  (None, 4, 6, 384)            0         ['batch_normalization_88[0][0]
#                                                                     ']
#
#  activation_91 (Activation)  (None, 4, 6, 384)            0         ['batch_normalization_91[0][0]
#                                                                     ']
#
#  activation_92 (Activation)  (None, 4, 6, 384)            0         ['batch_normalization_92[0][0]
#                                                                     ']
#
#  batch_normalization_93 (Ba  (None, 4, 6, 192)            576       ['conv2d_93[0][0]']
#  tchNormalization)
#
#  activation_85 (Activation)  (None, 4, 6, 320)            0         ['batch_normalization_85[0][0]
#                                                                     ']
#
#  mixed9_1 (Concatenate)      (None, 4, 6, 768)            0         ['activation_87[0][0]',
#                                                                      'activation_88[0][0]']
#
#  concatenate_1 (Concatenate  (None, 4, 6, 768)            0         ['activation_91[0][0]',
#  )                                                                   'activation_92[0][0]']
#
#  activation_93 (Activation)  (None, 4, 6, 192)            0         ['batch_normalization_93[0][0]
#                                                                     ']
#
#  mixed10 (Concatenate)       (None, 4, 6, 2048)           0         ['activation_85[0][0]',
#                                                                      'mixed9_1[0][0]',
#                                                                      'concatenate_1[0][0]',
#                                                                      'activation_93[0][0]']
#
#  global_max_pooling2d (Glob  (None, 2048)                 0         ['mixed10[0][0]']
#  alMaxPooling2D)
#
#  dense (Dense)               (None, 512)                  1049088   ['global_max_pooling2d[0][0]']
#
#  dropout (Dropout)           (None, 512)                  0         ['dense[0][0]']
#
#  dense_1 (Dense)             (None, 7)                    3591      ['dropout[0][0]']
#
# ==================================================================================================
# Total params: 22855463 (87.19 MB)
# Trainable params: 1052679 (4.02 MB)
# Non-trainable params: 21802784 (83.17 MB)
# __________________________________________________________________________________________________

# %% [markdown]
# ## Training
#
# Here we retrain using the whole model instead of performing transfer learning. The reason for this is the issue with batch-normalization layer implemented in Keras. During training the network will always use the mini-batch statistics either the BN layer is frozen or not; also during inference it will use the previously learned statistics of the frozen BN layers. As a result, if we fine-tune the top layers, their weights will be adjusted to the mean/variance of the new dataset. Nevertheless, during inference they will receive data which are scaled differently because the mean/variance of the original dataset will be used. Consequently, performing transfer-learning with InceptionV3 will result in very bad validation accuracy. For solution to this issue, have a look at: https://github.com/keras-team/keras/pull/9965 and https://github.com/keras-team/keras/issues/9214. For now, let's just retrain the whole model with very small learning_rate = 0.0001 and large momentum and a learning_rate_reduction function that halves the learning whenever the validation accuracy doesn't change for a 3 consecutive epochs. We will train for only 20 epochs so that the weights of the original pretrained model won't change too much and overfit the train data.

# %% [markdown]
# ### Feature Extraction
#
# Before we even retrain our model, it's better that we freeze all the layers in InceptionV3 and just train our top fully-connected and classification layers so that the weights for these layers won't be too random. The intuition for this is that if we didn't perform feature-extraction, then the gradient would be too large and would change the pretrained weights too much.

# %%
train_datagen = ImageDataGenerator(rotation_range=60, width_shift_range=0.2, height_shift_range=0.2,
                                   shear_range=0.2, zoom_range=0.2, fill_mode='nearest')

train_datagen.fit(X_train)

val_datagen = ImageDataGenerator()
val_datagen.fit(X_val)

# %%
batch_size = 64
epochs = 3
history = model.fit_generator(train_datagen.flow(X_train,y_train, batch_size=batch_size),
                              epochs = epochs, validation_data = val_datagen.flow(X_val, y_val),
                              verbose = 1, steps_per_epoch=(X_train.shape[0] // batch_size), 
                              validation_steps=(X_val.shape[0] // batch_size))
# Out:
# /tmp/ipykernel_26/3971016608.py:3: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   history = model.fit_generator(train_datagen.flow(X_train,y_train, batch_size=batch_size),
# Epoch 1/3
# 126/126 [==============================] - 104s 759ms/step - loss: 1.4884 - accuracy: 0.6040 - val_loss: 1.1021 - val_accuracy: 0.6518
# Epoch 2/3
# 126/126 [==============================] - 91s 722ms/step - loss: 1.0230 - accuracy: 0.6683 - val_loss: 0.9159 - val_accuracy: 0.6808
# Epoch 3/3
# 126/126 [==============================] - 92s 728ms/step - loss: 0.9679 - accuracy: 0.6769 - val_loss: 0.9796 - val_accuracy: 0.6786

# %% [markdown]
# ### Retraining
#
# Now, we are retraining the whole models. The goal is to just tune the weights a bit for our dataset and avoid changing the pretrained weights too much!

# %%
for layer in pre_trained_model.layers:
    layer.trainable = True

# %%
optimizer = Adam(lr=0.0001, beta_1=0.9, beta_2=0.999, epsilon=None, decay=0.0, amsgrad=False)
model.compile(loss='categorical_crossentropy',
              optimizer=optimizer,
              metrics=['acc'])

# %%
learning_rate_reduction = ReduceLROnPlateau(monitor='val_acc', patience=3, verbose=1, factor=0.5, 
                                            min_lr=0.000001, cooldown=2)

# %%
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_1 (InputLayer)        [(None, 192, 256, 3)]        0         []
#
#  conv2d (Conv2D)             (None, 95, 127, 32)          864       ['input_1[0][0]']
#
#  batch_normalization (Batch  (None, 95, 127, 32)          96        ['conv2d[0][0]']
#  Normalization)
#
#  activation (Activation)     (None, 95, 127, 32)          0         ['batch_normalization[0][0]']
#
#  conv2d_1 (Conv2D)           (None, 93, 125, 32)          9216      ['activation[0][0]']
#
#  batch_normalization_1 (Bat  (None, 93, 125, 32)          96        ['conv2d_1[0][0]']
#  chNormalization)
#
#  activation_1 (Activation)   (None, 93, 125, 32)          0         ['batch_normalization_1[0][0]'
#                                                                     ]
#
#  conv2d_2 (Conv2D)           (None, 93, 125, 64)          18432     ['activation_1[0][0]']
#
#  batch_normalization_2 (Bat  (None, 93, 125, 64)          192       ['conv2d_2[0][0]']
#  chNormalization)
#
#  activation_2 (Activation)   (None, 93, 125, 64)          0         ['batch_normalization_2[0][0]'
#                                                                     ]
#
#  max_pooling2d (MaxPooling2  (None, 46, 62, 64)           0         ['activation_2[0][0]']
#  D)
#
#  conv2d_3 (Conv2D)           (None, 46, 62, 80)           5120      ['max_pooling2d[0][0]']
#
#  batch_normalization_3 (Bat  (None, 46, 62, 80)           240       ['conv2d_3[0][0]']
#  chNormalization)
#
#  activation_3 (Activation)   (None, 46, 62, 80)           0         ['batch_normalization_3[0][0]'
#                                                                     ]
#
#  conv2d_4 (Conv2D)           (None, 44, 60, 192)          138240    ['activation_3[0][0]']
#
#  batch_normalization_4 (Bat  (None, 44, 60, 192)          576       ['conv2d_4[0][0]']
#  chNormalization)
#
#  activation_4 (Activation)   (None, 44, 60, 192)          0         ['batch_normalization_4[0][0]'
#                                                                     ]
#
#  max_pooling2d_1 (MaxPoolin  (None, 21, 29, 192)          0         ['activation_4[0][0]']
#  g2D)
#
#  conv2d_8 (Conv2D)           (None, 21, 29, 64)           12288     ['max_pooling2d_1[0][0]']
#
#  batch_normalization_8 (Bat  (None, 21, 29, 64)           192       ['conv2d_8[0][0]']
#  chNormalization)
#
#  activation_8 (Activation)   (None, 21, 29, 64)           0         ['batch_normalization_8[0][0]'
#                                                                     ]
#
#  conv2d_6 (Conv2D)           (None, 21, 29, 48)           9216      ['max_pooling2d_1[0][0]']
#
#  conv2d_9 (Conv2D)           (None, 21, 29, 96)           55296     ['activation_8[0][0]']
#
#  batch_normalization_6 (Bat  (None, 21, 29, 48)           144       ['conv2d_6[0][0]']
#  chNormalization)
#
#  batch_normalization_9 (Bat  (None, 21, 29, 96)           288       ['conv2d_9[0][0]']
#  chNormalization)
#
#  activation_6 (Activation)   (None, 21, 29, 48)           0         ['batch_normalization_6[0][0]'
#                                                                     ]
#
#  activation_9 (Activation)   (None, 21, 29, 96)           0         ['batch_normalization_9[0][0]'
#                                                                     ]
#
#  average_pooling2d (Average  (None, 21, 29, 192)          0         ['max_pooling2d_1[0][0]']
#  Pooling2D)
#
#  conv2d_5 (Conv2D)           (None, 21, 29, 64)           12288     ['max_pooling2d_1[0][0]']
#
#  conv2d_7 (Conv2D)           (None, 21, 29, 64)           76800     ['activation_6[0][0]']
#
#  conv2d_10 (Conv2D)          (None, 21, 29, 96)           82944     ['activation_9[0][0]']
#
#  conv2d_11 (Conv2D)          (None, 21, 29, 32)           6144      ['average_pooling2d[0][0]']
#
#  batch_normalization_5 (Bat  (None, 21, 29, 64)           192       ['conv2d_5[0][0]']
#  chNormalization)
#
#  batch_normalization_7 (Bat  (None, 21, 29, 64)           192       ['conv2d_7[0][0]']
#  chNormalization)
#
#  batch_normalization_10 (Ba  (None, 21, 29, 96)           288       ['conv2d_10[0][0]']
#  tchNormalization)
#
#  batch_normalization_11 (Ba  (None, 21, 29, 32)           96        ['conv2d_11[0][0]']
#  tchNormalization)
#
#  activation_5 (Activation)   (None, 21, 29, 64)           0         ['batch_normalization_5[0][0]'
#                                                                     ]
#
#  activation_7 (Activation)   (None, 21, 29, 64)           0         ['batch_normalization_7[0][0]'
#                                                                     ]
#
#  activation_10 (Activation)  (None, 21, 29, 96)           0         ['batch_normalization_10[0][0]
#                                                                     ']
#
#  activation_11 (Activation)  (None, 21, 29, 32)           0         ['batch_normalization_11[0][0]
#                                                                     ']
#
#  mixed0 (Concatenate)        (None, 21, 29, 256)          0         ['activation_5[0][0]',
#                                                                      'activation_7[0][0]',
#                                                                      'activation_10[0][0]',
#                                                                      'activation_11[0][0]']
#
#  conv2d_15 (Conv2D)          (None, 21, 29, 64)           16384     ['mixed0[0][0]']
#
#  batch_normalization_15 (Ba  (None, 21, 29, 64)           192       ['conv2d_15[0][0]']
#  tchNormalization)
#
#  activation_15 (Activation)  (None, 21, 29, 64)           0         ['batch_normalization_15[0][0]
#                                                                     ']
#
#  conv2d_13 (Conv2D)          (None, 21, 29, 48)           12288     ['mixed0[0][0]']
#
#  conv2d_16 (Conv2D)          (None, 21, 29, 96)           55296     ['activation_15[0][0]']
#
#  batch_normalization_13 (Ba  (None, 21, 29, 48)           144       ['conv2d_13[0][0]']
#  tchNormalization)
#
#  batch_normalization_16 (Ba  (None, 21, 29, 96)           288       ['conv2d_16[0][0]']
#  tchNormalization)
#
#  activation_13 (Activation)  (None, 21, 29, 48)           0         ['batch_normalization_13[0][0]
#                                                                     ']
#
#  activation_16 (Activation)  (None, 21, 29, 96)           0         ['batch_normalization_16[0][0]
#                                                                     ']
#
#  average_pooling2d_1 (Avera  (None, 21, 29, 256)          0         ['mixed0[0][0]']
#  gePooling2D)
#
#  conv2d_12 (Conv2D)          (None, 21, 29, 64)           16384     ['mixed0[0][0]']
#
#  conv2d_14 (Conv2D)          (None, 21, 29, 64)           76800     ['activation_13[0][0]']
#
#  conv2d_17 (Conv2D)          (None, 21, 29, 96)           82944     ['activation_16[0][0]']
#
#  conv2d_18 (Conv2D)          (None, 21, 29, 64)           16384     ['average_pooling2d_1[0][0]']
#
#  batch_normalization_12 (Ba  (None, 21, 29, 64)           192       ['conv2d_12[0][0]']
#  tchNormalization)
#
#  batch_normalization_14 (Ba  (None, 21, 29, 64)           192       ['conv2d_14[0][0]']
#  tchNormalization)
#
#  batch_normalization_17 (Ba  (None, 21, 29, 96)           288       ['conv2d_17[0][0]']
#  tchNormalization)
#
#  batch_normalization_18 (Ba  (None, 21, 29, 64)           192       ['conv2d_18[0][0]']
#  tchNormalization)
#
#  activation_12 (Activation)  (None, 21, 29, 64)           0         ['batch_normalization_12[0][0]
#                                                                     ']
#
#  activation_14 (Activation)  (None, 21, 29, 64)           0         ['batch_normalization_14[0][0]
#                                                                     ']
#
#  activation_17 (Activation)  (None, 21, 29, 96)           0         ['batch_normalization_17[0][0]
#                                                                     ']
#
#  activation_18 (Activation)  (None, 21, 29, 64)           0         ['batch_normalization_18[0][0]
#                                                                     ']
#
#  mixed1 (Concatenate)        (None, 21, 29, 288)          0         ['activation_12[0][0]',
#                                                                      'activation_14[0][0]',
#                                                                      'activation_17[0][0]',
#                                                                      'activation_18[0][0]']
#
#  conv2d_22 (Conv2D)          (None, 21, 29, 64)           18432     ['mixed1[0][0]']
#
#  batch_normalization_22 (Ba  (None, 21, 29, 64)           192       ['conv2d_22[0][0]']
#  tchNormalization)
#
#  activation_22 (Activation)  (None, 21, 29, 64)           0         ['batch_normalization_22[0][0]
#                                                                     ']
#
#  conv2d_20 (Conv2D)          (None, 21, 29, 48)           13824     ['mixed1[0][0]']
#
#  conv2d_23 (Conv2D)          (None, 21, 29, 96)           55296     ['activation_22[0][0]']
#
#  batch_normalization_20 (Ba  (None, 21, 29, 48)           144       ['conv2d_20[0][0]']
#  tchNormalization)
#
#  batch_normalization_23 (Ba  (None, 21, 29, 96)           288       ['conv2d_23[0][0]']
#  tchNormalization)
#
#  activation_20 (Activation)  (None, 21, 29, 48)           0         ['batch_normalization_20[0][0]
#                                                                     ']
#
#  activation_23 (Activation)  (None, 21, 29, 96)           0         ['batch_normalization_23[0][0]
#                                                                     ']
#
#  average_pooling2d_2 (Avera  (None, 21, 29, 288)          0         ['mixed1[0][0]']
#  gePooling2D)
#
#  conv2d_19 (Conv2D)          (None, 21, 29, 64)           18432     ['mixed1[0][0]']
#
#  conv2d_21 (Conv2D)          (None, 21, 29, 64)           76800     ['activation_20[0][0]']
#
#  conv2d_24 (Conv2D)          (None, 21, 29, 96)           82944     ['activation_23[0][0]']
#
#  conv2d_25 (Conv2D)          (None, 21, 29, 64)           18432     ['average_pooling2d_2[0][0]']
#
#  batch_normalization_19 (Ba  (None, 21, 29, 64)           192       ['conv2d_19[0][0]']
#  tchNormalization)
#
#  batch_normalization_21 (Ba  (None, 21, 29, 64)           192       ['conv2d_21[0][0]']
#  tchNormalization)
#
#  batch_normalization_24 (Ba  (None, 21, 29, 96)           288       ['conv2d_24[0][0]']
#  tchNormalization)
#
#  batch_normalization_25 (Ba  (None, 21, 29, 64)           192       ['conv2d_25[0][0]']
#  tchNormalization)
#
#  activation_19 (Activation)  (None, 21, 29, 64)           0         ['batch_normalization_19[0][0]
#                                                                     ']
#
#  activation_21 (Activation)  (None, 21, 29, 64)           0         ['batch_normalization_21[0][0]
#                                                                     ']
#
#  activation_24 (Activation)  (None, 21, 29, 96)           0         ['batch_normalization_24[0][0]
#                                                                     ']
#
#  activation_25 (Activation)  (None, 21, 29, 64)           0         ['batch_normalization_25[0][0]
#                                                                     ']
#
#  mixed2 (Concatenate)        (None, 21, 29, 288)          0         ['activation_19[0][0]',
#                                                                      'activation_21[0][0]',
#                                                                      'activation_24[0][0]',
#                                                                      'activation_25[0][0]']
#
#  conv2d_27 (Conv2D)          (None, 21, 29, 64)           18432     ['mixed2[0][0]']
#
#  batch_normalization_27 (Ba  (None, 21, 29, 64)           192       ['conv2d_27[0][0]']
#  tchNormalization)
#
#  activation_27 (Activation)  (None, 21, 29, 64)           0         ['batch_normalization_27[0][0]
#                                                                     ']
#
#  conv2d_28 (Conv2D)          (None, 21, 29, 96)           55296     ['activation_27[0][0]']
#
#  batch_normalization_28 (Ba  (None, 21, 29, 96)           288       ['conv2d_28[0][0]']
#  tchNormalization)
#
#  activation_28 (Activation)  (None, 21, 29, 96)           0         ['batch_normalization_28[0][0]
#                                                                     ']
#
#  conv2d_26 (Conv2D)          (None, 10, 14, 384)          995328    ['mixed2[0][0]']
#
#  conv2d_29 (Conv2D)          (None, 10, 14, 96)           82944     ['activation_28[0][0]']
#
#  batch_normalization_26 (Ba  (None, 10, 14, 384)          1152      ['conv2d_26[0][0]']
#  tchNormalization)
#
#  batch_normalization_29 (Ba  (None, 10, 14, 96)           288       ['conv2d_29[0][0]']
#  tchNormalization)
#
#  activation_26 (Activation)  (None, 10, 14, 384)          0         ['batch_normalization_26[0][0]
#                                                                     ']
#
#  activation_29 (Activation)  (None, 10, 14, 96)           0         ['batch_normalization_29[0][0]
#                                                                     ']
#
#  max_pooling2d_2 (MaxPoolin  (None, 10, 14, 288)          0         ['mixed2[0][0]']
#  g2D)
#
#  mixed3 (Concatenate)        (None, 10, 14, 768)          0         ['activation_26[0][0]',
#                                                                      'activation_29[0][0]',
#                                                                      'max_pooling2d_2[0][0]']
#
#  conv2d_34 (Conv2D)          (None, 10, 14, 128)          98304     ['mixed3[0][0]']
#
#  batch_normalization_34 (Ba  (None, 10, 14, 128)          384       ['conv2d_34[0][0]']
#  tchNormalization)
#
#  activation_34 (Activation)  (None, 10, 14, 128)          0         ['batch_normalization_34[0][0]
#                                                                     ']
#
#  conv2d_35 (Conv2D)          (None, 10, 14, 128)          114688    ['activation_34[0][0]']
#
#  batch_normalization_35 (Ba  (None, 10, 14, 128)          384       ['conv2d_35[0][0]']
#  tchNormalization)
#
#  activation_35 (Activation)  (None, 10, 14, 128)          0         ['batch_normalization_35[0][0]
#                                                                     ']
#
#  conv2d_31 (Conv2D)          (None, 10, 14, 128)          98304     ['mixed3[0][0]']
#
#  conv2d_36 (Conv2D)          (None, 10, 14, 128)          114688    ['activation_35[0][0]']
#
#  batch_normalization_31 (Ba  (None, 10, 14, 128)          384       ['conv2d_31[0][0]']
#  tchNormalization)
#
#  batch_normalization_36 (Ba  (None, 10, 14, 128)          384       ['conv2d_36[0][0]']
#  tchNormalization)
#
#  activation_31 (Activation)  (None, 10, 14, 128)          0         ['batch_normalization_31[0][0]
#                                                                     ']
#
#  activation_36 (Activation)  (None, 10, 14, 128)          0         ['batch_normalization_36[0][0]
#                                                                     ']
#
#  conv2d_32 (Conv2D)          (None, 10, 14, 128)          114688    ['activation_31[0][0]']
#
#  conv2d_37 (Conv2D)          (None, 10, 14, 128)          114688    ['activation_36[0][0]']
#
#  batch_normalization_32 (Ba  (None, 10, 14, 128)          384       ['conv2d_32[0][0]']
#  tchNormalization)
#
#  batch_normalization_37 (Ba  (None, 10, 14, 128)          384       ['conv2d_37[0][0]']
#  tchNormalization)
#
#  activation_32 (Activation)  (None, 10, 14, 128)          0         ['batch_normalization_32[0][0]
#                                                                     ']
#
#  activation_37 (Activation)  (None, 10, 14, 128)          0         ['batch_normalization_37[0][0]
#                                                                     ']
#
#  average_pooling2d_3 (Avera  (None, 10, 14, 768)          0         ['mixed3[0][0]']
#  gePooling2D)
#
#  conv2d_30 (Conv2D)          (None, 10, 14, 192)          147456    ['mixed3[0][0]']
#
#  conv2d_33 (Conv2D)          (None, 10, 14, 192)          172032    ['activation_32[0][0]']
#
#  conv2d_38 (Conv2D)          (None, 10, 14, 192)          172032    ['activation_37[0][0]']
#
#  conv2d_39 (Conv2D)          (None, 10, 14, 192)          147456    ['average_pooling2d_3[0][0]']
#
#  batch_normalization_30 (Ba  (None, 10, 14, 192)          576       ['conv2d_30[0][0]']
#  tchNormalization)
#
#  batch_normalization_33 (Ba  (None, 10, 14, 192)          576       ['conv2d_33[0][0]']
#  tchNormalization)
#
#  batch_normalization_38 (Ba  (None, 10, 14, 192)          576       ['conv2d_38[0][0]']
#  tchNormalization)
#
#  batch_normalization_39 (Ba  (None, 10, 14, 192)          576       ['conv2d_39[0][0]']
#  tchNormalization)
#
#  activation_30 (Activation)  (None, 10, 14, 192)          0         ['batch_normalization_30[0][0]
#                                                                     ']
#
#  activation_33 (Activation)  (None, 10, 14, 192)          0         ['batch_normalization_33[0][0]
#                                                                     ']
#
#  activation_38 (Activation)  (None, 10, 14, 192)          0         ['batch_normalization_38[0][0]
#                                                                     ']
#
#  activation_39 (Activation)  (None, 10, 14, 192)          0         ['batch_normalization_39[0][0]
#                                                                     ']
#
#  mixed4 (Concatenate)        (None, 10, 14, 768)          0         ['activation_30[0][0]',
#                                                                      'activation_33[0][0]',
#                                                                      'activation_38[0][0]',
#                                                                      'activation_39[0][0]']
#
#  conv2d_44 (Conv2D)          (None, 10, 14, 160)          122880    ['mixed4[0][0]']
#
#  batch_normalization_44 (Ba  (None, 10, 14, 160)          480       ['conv2d_44[0][0]']
#  tchNormalization)
#
#  activation_44 (Activation)  (None, 10, 14, 160)          0         ['batch_normalization_44[0][0]
#                                                                     ']
#
#  conv2d_45 (Conv2D)          (None, 10, 14, 160)          179200    ['activation_44[0][0]']
#
#  batch_normalization_45 (Ba  (None, 10, 14, 160)          480       ['conv2d_45[0][0]']
#  tchNormalization)
#
#  activation_45 (Activation)  (None, 10, 14, 160)          0         ['batch_normalization_45[0][0]
#                                                                     ']
#
#  conv2d_41 (Conv2D)          (None, 10, 14, 160)          122880    ['mixed4[0][0]']
#
#  conv2d_46 (Conv2D)          (None, 10, 14, 160)          179200    ['activation_45[0][0]']
#
#  batch_normalization_41 (Ba  (None, 10, 14, 160)          480       ['conv2d_41[0][0]']
#  tchNormalization)
#
#  batch_normalization_46 (Ba  (None, 10, 14, 160)          480       ['conv2d_46[0][0]']
#  tchNormalization)
#
#  activation_41 (Activation)  (None, 10, 14, 160)          0         ['batch_normalization_41[0][0]
#                                                                     ']
#
#  activation_46 (Activation)  (None, 10, 14, 160)          0         ['batch_normalization_46[0][0]
#                                                                     ']
#
#  conv2d_42 (Conv2D)          (None, 10, 14, 160)          179200    ['activation_41[0][0]']
#
#  conv2d_47 (Conv2D)          (None, 10, 14, 160)          179200    ['activation_46[0][0]']
#
#  batch_normalization_42 (Ba  (None, 10, 14, 160)          480       ['conv2d_42[0][0]']
#  tchNormalization)
#
#  batch_normalization_47 (Ba  (None, 10, 14, 160)          480       ['conv2d_47[0][0]']
#  tchNormalization)
#
#  activation_42 (Activation)  (None, 10, 14, 160)          0         ['batch_normalization_42[0][0]
#                                                                     ']
#
#  activation_47 (Activation)  (None, 10, 14, 160)          0         ['batch_normalization_47[0][0]
#                                                                     ']
#
#  average_pooling2d_4 (Avera  (None, 10, 14, 768)          0         ['mixed4[0][0]']
#  gePooling2D)
#
#  conv2d_40 (Conv2D)          (None, 10, 14, 192)          147456    ['mixed4[0][0]']
#
#  conv2d_43 (Conv2D)          (None, 10, 14, 192)          215040    ['activation_42[0][0]']
#
#  conv2d_48 (Conv2D)          (None, 10, 14, 192)          215040    ['activation_47[0][0]']
#
#  conv2d_49 (Conv2D)          (None, 10, 14, 192)          147456    ['average_pooling2d_4[0][0]']
#
#  batch_normalization_40 (Ba  (None, 10, 14, 192)          576       ['conv2d_40[0][0]']
#  tchNormalization)
#
#  batch_normalization_43 (Ba  (None, 10, 14, 192)          576       ['conv2d_43[0][0]']
#  tchNormalization)
#
#  batch_normalization_48 (Ba  (None, 10, 14, 192)          576       ['conv2d_48[0][0]']
#  tchNormalization)
#
#  batch_normalization_49 (Ba  (None, 10, 14, 192)          576       ['conv2d_49[0][0]']
#  tchNormalization)
#
#  activation_40 (Activation)  (None, 10, 14, 192)          0         ['batch_normalization_40[0][0]
#                                                                     ']
#
#  activation_43 (Activation)  (None, 10, 14, 192)          0         ['batch_normalization_43[0][0]
#                                                                     ']
#
#  activation_48 (Activation)  (None, 10, 14, 192)          0         ['batch_normalization_48[0][0]
#                                                                     ']
#
#  activation_49 (Activation)  (None, 10, 14, 192)          0         ['batch_normalization_49[0][0]
#                                                                     ']
#
#  mixed5 (Concatenate)        (None, 10, 14, 768)          0         ['activation_40[0][0]',
#                                                                      'activation_43[0][0]',
#                                                                      'activation_48[0][0]',
#                                                                      'activation_49[0][0]']
#
#  conv2d_54 (Conv2D)          (None, 10, 14, 160)          122880    ['mixed5[0][0]']
#
#  batch_normalization_54 (Ba  (None, 10, 14, 160)          480       ['conv2d_54[0][0]']
#  tchNormalization)
#
#  activation_54 (Activation)  (None, 10, 14, 160)          0         ['batch_normalization_54[0][0]
#                                                                     ']
#
#  conv2d_55 (Conv2D)          (None, 10, 14, 160)          179200    ['activation_54[0][0]']
#
#  batch_normalization_55 (Ba  (None, 10, 14, 160)          480       ['conv2d_55[0][0]']
#  tchNormalization)
#
#  activation_55 (Activation)  (None, 10, 14, 160)          0         ['batch_normalization_55[0][0]
#                                                                     ']
#
#  conv2d_51 (Conv2D)          (None, 10, 14, 160)          122880    ['mixed5[0][0]']
#
#  conv2d_56 (Conv2D)          (None, 10, 14, 160)          179200    ['activation_55[0][0]']
#
#  batch_normalization_51 (Ba  (None, 10, 14, 160)          480       ['conv2d_51[0][0]']
#  tchNormalization)
#
#  batch_normalization_56 (Ba  (None, 10, 14, 160)          480       ['conv2d_56[0][0]']
#  tchNormalization)
#
#  activation_51 (Activation)  (None, 10, 14, 160)          0         ['batch_normalization_51[0][0]
# ...
#
#  conv2d_78 (Conv2D)          (None, 4, 6, 384)            442368    ['activation_77[0][0]']
#
#  conv2d_79 (Conv2D)          (None, 4, 6, 384)            442368    ['activation_77[0][0]']
#
#  conv2d_82 (Conv2D)          (None, 4, 6, 384)            442368    ['activation_81[0][0]']
#
#  conv2d_83 (Conv2D)          (None, 4, 6, 384)            442368    ['activation_81[0][0]']
#
#  average_pooling2d_7 (Avera  (None, 4, 6, 1280)           0         ['mixed8[0][0]']
#  gePooling2D)
#
#  conv2d_76 (Conv2D)          (None, 4, 6, 320)            409600    ['mixed8[0][0]']
#
#  batch_normalization_78 (Ba  (None, 4, 6, 384)            1152      ['conv2d_78[0][0]']
#  tchNormalization)
#
#  batch_normalization_79 (Ba  (None, 4, 6, 384)            1152      ['conv2d_79[0][0]']
#  tchNormalization)
#
#  batch_normalization_82 (Ba  (None, 4, 6, 384)            1152      ['conv2d_82[0][0]']
#  tchNormalization)
#
#  batch_normalization_83 (Ba  (None, 4, 6, 384)            1152      ['conv2d_83[0][0]']
#  tchNormalization)
#
#  conv2d_84 (Conv2D)          (None, 4, 6, 192)            245760    ['average_pooling2d_7[0][0]']
#
#  batch_normalization_76 (Ba  (None, 4, 6, 320)            960       ['conv2d_76[0][0]']
#  tchNormalization)
#
#  activation_78 (Activation)  (None, 4, 6, 384)            0         ['batch_normalization_78[0][0]
#                                                                     ']
#
#  activation_79 (Activation)  (None, 4, 6, 384)            0         ['batch_normalization_79[0][0]
#                                                                     ']
#
#  activation_82 (Activation)  (None, 4, 6, 384)            0         ['batch_normalization_82[0][0]
#                                                                     ']
#
#  activation_83 (Activation)  (None, 4, 6, 384)            0         ['batch_normalization_83[0][0]
#                                                                     ']
#
#  batch_normalization_84 (Ba  (None, 4, 6, 192)            576       ['conv2d_84[0][0]']
#  tchNormalization)
#
#  activation_76 (Activation)  (None, 4, 6, 320)            0         ['batch_normalization_76[0][0]
#                                                                     ']
#
#  mixed9_0 (Concatenate)      (None, 4, 6, 768)            0         ['activation_78[0][0]',
#                                                                      'activation_79[0][0]']
#
#  concatenate (Concatenate)   (None, 4, 6, 768)            0         ['activation_82[0][0]',
#                                                                      'activation_83[0][0]']
#
#  activation_84 (Activation)  (None, 4, 6, 192)            0         ['batch_normalization_84[0][0]
#                                                                     ']
#
#  mixed9 (Concatenate)        (None, 4, 6, 2048)           0         ['activation_76[0][0]',
#                                                                      'mixed9_0[0][0]',
#                                                                      'concatenate[0][0]',
#                                                                      'activation_84[0][0]']
#
#  conv2d_89 (Conv2D)          (None, 4, 6, 448)            917504    ['mixed9[0][0]']
#
#  batch_normalization_89 (Ba  (None, 4, 6, 448)            1344      ['conv2d_89[0][0]']
#  tchNormalization)
#
#  activation_89 (Activation)  (None, 4, 6, 448)            0         ['batch_normalization_89[0][0]
#                                                                     ']
#
#  conv2d_86 (Conv2D)          (None, 4, 6, 384)            786432    ['mixed9[0][0]']
#
#  conv2d_90 (Conv2D)          (None, 4, 6, 384)            1548288   ['activation_89[0][0]']
#
#  batch_normalization_86 (Ba  (None, 4, 6, 384)            1152      ['conv2d_86[0][0]']
#  tchNormalization)
#
#  batch_normalization_90 (Ba  (None, 4, 6, 384)            1152      ['conv2d_90[0][0]']
#  tchNormalization)
#
#  activation_86 (Activation)  (None, 4, 6, 384)            0         ['batch_normalization_86[0][0]
#                                                                     ']
#
#  activation_90 (Activation)  (None, 4, 6, 384)            0         ['batch_normalization_90[0][0]
#                                                                     ']
#
#  conv2d_87 (Conv2D)          (None, 4, 6, 384)            442368    ['activation_86[0][0]']
#
#  conv2d_88 (Conv2D)          (None, 4, 6, 384)            442368    ['activation_86[0][0]']
#
#  conv2d_91 (Conv2D)          (None, 4, 6, 384)            442368    ['activation_90[0][0]']
#
#  conv2d_92 (Conv2D)          (None, 4, 6, 384)            442368    ['activation_90[0][0]']
#
#  average_pooling2d_8 (Avera  (None, 4, 6, 2048)           0         ['mixed9[0][0]']
#  gePooling2D)
#
#  conv2d_85 (Conv2D)          (None, 4, 6, 320)            655360    ['mixed9[0][0]']
#
#  batch_normalization_87 (Ba  (None, 4, 6, 384)            1152      ['conv2d_87[0][0]']
#  tchNormalization)
#
#  batch_normalization_88 (Ba  (None, 4, 6, 384)            1152      ['conv2d_88[0][0]']
#  tchNormalization)
#
#  batch_normalization_91 (Ba  (None, 4, 6, 384)            1152      ['conv2d_91[0][0]']
#  tchNormalization)
#
#  batch_normalization_92 (Ba  (None, 4, 6, 384)            1152      ['conv2d_92[0][0]']
#  tchNormalization)
#
#  conv2d_93 (Conv2D)          (None, 4, 6, 192)            393216    ['average_pooling2d_8[0][0]']
#
#  batch_normalization_85 (Ba  (None, 4, 6, 320)            960       ['conv2d_85[0][0]']
#  tchNormalization)
#
#  activation_87 (Activation)  (None, 4, 6, 384)            0         ['batch_normalization_87[0][0]
#                                                                     ']
#
#  activation_88 (Activation)  (None, 4, 6, 384)            0         ['batch_normalization_88[0][0]
#                                                                     ']
#
#  activation_91 (Activation)  (None, 4, 6, 384)            0         ['batch_normalization_91[0][0]
#                                                                     ']
#
#  activation_92 (Activation)  (None, 4, 6, 384)            0         ['batch_normalization_92[0][0]
#                                                                     ']
#
#  batch_normalization_93 (Ba  (None, 4, 6, 192)            576       ['conv2d_93[0][0]']
#  tchNormalization)
#
#  activation_85 (Activation)  (None, 4, 6, 320)            0         ['batch_normalization_85[0][0]
#                                                                     ']
#
#  mixed9_1 (Concatenate)      (None, 4, 6, 768)            0         ['activation_87[0][0]',
#                                                                      'activation_88[0][0]']
#
#  concatenate_1 (Concatenate  (None, 4, 6, 768)            0         ['activation_91[0][0]',
#  )                                                                   'activation_92[0][0]']
#
#  activation_93 (Activation)  (None, 4, 6, 192)            0         ['batch_normalization_93[0][0]
#                                                                     ']
#
#  mixed10 (Concatenate)       (None, 4, 6, 2048)           0         ['activation_85[0][0]',
#                                                                      'mixed9_1[0][0]',
#                                                                      'concatenate_1[0][0]',
#                                                                      'activation_93[0][0]']
#
#  global_max_pooling2d (Glob  (None, 2048)                 0         ['mixed10[0][0]']
#  alMaxPooling2D)
#
#  dense (Dense)               (None, 512)                  1049088   ['global_max_pooling2d[0][0]']
#
#  dropout (Dropout)           (None, 512)                  0         ['dense[0][0]']
#
#  dense_1 (Dense)             (None, 7)                    3591      ['dropout[0][0]']
#
# ==================================================================================================
# Total params: 22855463 (87.19 MB)
# Trainable params: 22821031 (87.06 MB)
# Non-trainable params: 34432 (134.50 KB)
# __________________________________________________________________________________________________

# %%
batch_size = 64
epochs = 20
history = model.fit_generator(train_datagen.flow(X_train,y_train, batch_size=batch_size),
                              epochs = epochs, validation_data = val_datagen.flow(X_val, y_val),
                              verbose = 1, steps_per_epoch=(X_train.shape[0] // batch_size),
                              validation_steps=(X_val.shape[0] // batch_size),
                              callbacks=[learning_rate_reduction])
# Out:
# /tmp/ipykernel_26/88883534.py:3: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   history = model.fit_generator(train_datagen.flow(X_train,y_train, batch_size=batch_size),
# Epoch 1/20
# 126/126 [==============================] - 110s 768ms/step - loss: 0.8920 - acc: 0.6984 - val_loss: 1.3646 - val_acc: 0.6562 - lr: 1.0000e-04
# Epoch 2/20
# 126/126 [==============================] - 95s 752ms/step - loss: 0.7048 - acc: 0.7491 - val_loss: 0.7843 - val_acc: 0.7388 - lr: 1.0000e-04
# Epoch 3/20
# 126/126 [==============================] - 96s 757ms/step - loss: 0.5968 - acc: 0.7846 - val_loss: 0.5901 - val_acc: 0.7902 - lr: 1.0000e-04
# Epoch 4/20
# 126/126 [==============================] - 94s 739ms/step - loss: 0.5143 - acc: 0.8151 - val_loss: 0.5368 - val_acc: 0.8214 - lr: 1.0000e-04
# Epoch 5/20
# 126/126 [==============================] - 94s 747ms/step - loss: 0.4636 - acc: 0.8316 - val_loss: 0.4873 - val_acc: 0.8348 - lr: 1.0000e-04
# Epoch 6/20
# 126/126 [==============================] - 93s 733ms/step - loss: 0.4055 - acc: 0.8541 - val_loss: 0.5923 - val_acc: 0.8125 - lr: 1.0000e-04
# Epoch 7/20
# 126/126 [==============================] - 95s 754ms/step - loss: 0.3595 - acc: 0.8694 - val_loss: 0.5861 - val_acc: 0.8125 - lr: 1.0000e-04
# Epoch 8/20
# 126/126 [==============================] - ETA: 0s - loss: 0.3348 - acc: 0.8800
# Epoch 8: ReduceLROnPlateau reducing learning rate to 4.999999873689376e-05.
# 126/126 [==============================] - 96s 755ms/step - loss: 0.3348 - acc: 0.8800 - val_loss: 0.5728 - val_acc: 0.8214 - lr: 1.0000e-04
# Epoch 9/20
# 126/126 [==============================] - 94s 746ms/step - loss: 0.2659 - acc: 0.9028 - val_loss: 0.6686 - val_acc: 0.8147 - lr: 5.0000e-05
# Epoch 10/20
# 126/126 [==============================] - 95s 751ms/step - loss: 0.2294 - acc: 0.9176 - val_loss: 0.5807 - val_acc: 0.8214 - lr: 5.0000e-05
# Epoch 11/20
# 126/126 [==============================] - 94s 746ms/step - loss: 0.2084 - acc: 0.9257 - val_loss: 0.5531 - val_acc: 0.8616 - lr: 5.0000e-05
# Epoch 12/20
# 126/126 [==============================] - 95s 753ms/step - loss: 0.1900 - acc: 0.9297 - val_loss: 0.4961 - val_acc: 0.8549 - lr: 5.0000e-05
# Epoch 13/20
# 126/126 [==============================] - 95s 754ms/step - loss: 0.1862 - acc: 0.9338 - val_loss: 0.5519 - val_acc: 0.8683 - lr: 5.0000e-05
# Epoch 14/20
# 126/126 [==============================] - 95s 749ms/step - loss: 0.1648 - acc: 0.9413 - val_loss: 0.5342 - val_acc: 0.8594 - lr: 5.0000e-05
# Epoch 15/20
# 126/126 [==============================] - 95s 750ms/step - loss: 0.1550 - acc: 0.9453 - val_loss: 0.5378 - val_acc: 0.8460 - lr: 5.0000e-05
# Epoch 16/20
# 126/126 [==============================] - ETA: 0s - loss: 0.1424 - acc: 0.9507
# Epoch 16: ReduceLROnPlateau reducing learning rate to 2.499999936844688e-05.
# 126/126 [==============================] - 91s 717ms/step - loss: 0.1424 - acc: 0.9507 - val_loss: 0.5091 - val_acc: 0.8527 - lr: 5.0000e-05
# Epoch 17/20
# 126/126 [==============================] - 89s 703ms/step - loss: 0.1071 - acc: 0.9617 - val_loss: 0.6551 - val_acc: 0.8594 - lr: 2.5000e-05
# Epoch 18/20
# 126/126 [==============================] - 89s 702ms/step - loss: 0.1022 - acc: 0.9643 - val_loss: 0.7232 - val_acc: 0.8415 - lr: 2.5000e-05
# Epoch 19/20
# 126/126 [==============================] - 90s 708ms/step - loss: 0.0986 - acc: 0.9666 - val_loss: 0.5605 - val_acc: 0.8571 - lr: 2.5000e-05
# Epoch 20/20
# 126/126 [==============================] - 87s 689ms/step - loss: 0.0813 - acc: 0.9715 - val_loss: 0.4993 - val_acc: 0.8906 - lr: 2.5000e-05

# %%
loss_val, acc_val = model.evaluate(X_val, y_val, verbose=1)
print("Validation: accuracy = %f  ;  loss_v = %f" % (acc_val, loss_val))
# Out:
# 29/29 [==============================] - 3s 102ms/step - loss: 0.6834 - acc: 0.8614
# Validation: accuracy = 0.861419  ;  loss_v = 0.683374

# %% [markdown]
# Even though this model overfits the training data, we also observe some significant improvement with the validation accuracy. Our final validation accuracy is 86.9%, a nearly 10% improvement from the baseline model, which justifies some more training time. We can also see that this model is extremely "sensitive", a small change in learning rate can can change the model by a whole lot. Future work on choosing learning rate as well as monitor learning rate is needed for further improvement.

# %% [markdown]
# ## Testing
#
# Let's load in the intact test set and test our model

# %%
X_test = np.load("/kaggle/input/npyfiles/npy/256_192_test.npy")

# %%
y_test = np.load("/kaggle/input/npyfiles/npy/test_labels.npy")
y_test = to_categorical(y_test)

# %%
loss_test, acc_test = model.evaluate(X_test, y_test, verbose=1)
print("Test: accuracy = %f  ;  loss = %f" % (acc_test, loss_test))
# Out:
# 32/32 [==============================] - 3s 104ms/step - loss: 0.7403 - acc: 0.8383
# Test: accuracy = 0.838323  ;  loss = 0.740332

# %% [markdown]
# Achieving test accuracy of 86.8% after 20 training epochs is a good result! This experiment proved that the architecture and the weights of Inception trained on ImageNet help learning for a complete different domain dataset.

# %%
model.save("InceptionV3.h5")
# Out:
# /opt/conda/lib/python3.10/site-packages/keras/src/engine/training.py:3000: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(

# %%
# Retrieve a list of accuracy results on training and test data
# sets for each training epoch
acc = history.history['acc']
val_acc = history.history['val_acc']

# Retrieve a list of list results on training and test data
# sets for each training epoch
loss = history.history['loss']
val_loss = history.history['val_loss']

# Get number of epochs
epochs = range(len(acc))

# Plot training and validation accuracy per epoch
plt.plot(epochs, acc, label = "training")
plt.plot(epochs, val_acc, label = "validation")
plt.legend(loc="upper left")
plt.title('Training and validation accuracy')

plt.figure()

# Plot training and validation loss per epoch
plt.plot(epochs, loss, label = "training")
plt.plot(epochs, val_loss, label = "validation")
plt.legend(loc="upper right")
plt.title('Training and validation loss')
# Out:
# Text(0.5, 1.0, 'Training and validation loss')
